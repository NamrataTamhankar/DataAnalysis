# %% [markdown]
# merge 2 files

# %%
import pandas as pd
df = pd.read_parquet('C:/Users/a839429/Uber Data Analysis/Data/yellow_tripdata_2024-01.parquet')
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1               1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2               1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3               1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4               1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# ...           ...                  ...                   ...              ...
# 2964619         2  2024-01-31 23:45:59   2024-01-31 23:54:36              NaN
# 2964620         1  2024-01-31 23:13:07   2024-01-31 23:27:52              NaN
# 2964621         2  2024-01-31 23:19:00   2024-01-31 23:38:00              NaN
# 2964622         2  2024-01-31 23:07:23   2024-01-31 23:25:14              NaN
# 2964623         1  2024-01-31 23:58:25   2024-02-01 00:13:30              NaN
#
# ...

# %%
import pandas as pd
df = pd.read_parquet('C:/Users/a839429/Uber Data Analysis/Data/yellow_tripdata_2024-02.parquet')
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2024-02-01 00:04:45   2024-02-01 00:19:58              1.0
# 1               2  2024-02-01 00:56:31   2024-02-01 01:10:53              1.0
# 2               2  2024-02-01 00:07:50   2024-02-01 00:43:12              2.0
# 3               1  2024-02-01 00:01:49   2024-02-01 00:10:47              1.0
# 4               1  2024-02-01 00:37:35   2024-02-01 00:51:15              1.0
# ...           ...                  ...                   ...              ...
# 3007521         2  2024-02-29 23:20:17   2024-02-29 23:28:25              NaN
# 3007522         2  2024-02-29 23:38:37   2024-02-29 23:49:37              NaN
# 3007523         2  2024-02-29 23:14:40   2024-02-29 23:19:29              NaN
# 3007524         1  2024-02-29 23:12:06   2024-02-29 23:21:53              NaN
# 3007525         2  2024-02-29 23:16:42   2024-02-29 23:37:45              NaN
#
# ...

# %%
import pandas as pd

# Read the Parquet files into DataFrames
a = pd.read_parquet("C:/Users/a839429/Uber Data Analysis/Data/yellow_tripdata_2024-01.parquet")
b = pd.read_parquet("C:/Users/a839429/Uber Data Analysis/Data/yellow_tripdata_2024-02.parquet")

# Concatenate the DataFrames
merged = pd.concat([a, b])

# Write the merged DataFrame to a new Parquet file
parquet_file_path = "C:/Users/a839429/Uber Data Analysis/Data/2024.parquet"
merged.to_parquet(parquet_file_path, index=False)

# %%
import pandas as pd
df = pd.read_parquet('C:/Users/a839429/Uber Data Analysis/Data/2024.parquet')
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1               1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2               1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3               1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4               1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# ...           ...                  ...                   ...              ...
# 5972145         2  2024-02-29 23:20:17   2024-02-29 23:28:25              NaN
# 5972146         2  2024-02-29 23:38:37   2024-02-29 23:49:37              NaN
# 5972147         2  2024-02-29 23:14:40   2024-02-29 23:19:29              NaN
# 5972148         1  2024-02-29 23:12:06   2024-02-29 23:21:53              NaN
# 5972149         2  2024-02-29 23:16:42   2024-02-29 23:37:45              NaN
#
# ...
